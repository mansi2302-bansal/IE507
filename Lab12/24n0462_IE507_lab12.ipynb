# %%
n = int(input("enter a number: "))
number = 1
for i in range(1,n+1):
  for j in range(1,i+1):
    if number%2==0:
      print(f"{number}: Even",end=" ")
    else:
      print(f"{number}: Odd",end = " ")
    number = number+1
  print()
# Out:
# enter a number: 7
# 1: Odd
# 2: Even 3: Odd
# 4: Even 5: Odd 6: Even
# 7: Odd 8: Even 9: Odd 10: Even
# 11: Odd 12: Even 13: Odd 14: Even 15: Odd
# 16: Even 17: Odd 18: Even 19: Odd 20: Even 21: Odd
# 22: Even 23: Odd 24: Even 25: Odd 26: Even 27: Odd 28: Even

# %%
import random
random_num = random.randint(1,100)
while True:
  guess = int(input("enter a number between 1 and 100: "))
  if random_num == guess:
    print("Congratulations! You guessed it.")
    break
  elif random_num < guess:
    print("Too high! Try again.")
  else:
    print("Too low! Try again.")
# Out:
# enter a number between 1 and 100: 45
# Too high! Try again.
# enter a number between 1 and 100: 40
# Too high! Try again.
# enter a number between 1 and 100: 30
# Too high! Try again.
# enter a number between 1 and 100: 20
# Too low! Try again.
# enter a number between 1 and 100: 25
# Too low! Try again.
# enter a number between 1 and 100: 26
# Congratulations! You guessed it.

# %%
n = int(input("enter a number: "))
if str(n) == str(n)[::-1]:
  print("the given number is a palindrome")
else:
  print("not a palindrome")
for i in range(2,n):
  if n%i == 0:
    print(f"{n} is not a prime number")
    break
  else:
    print(f"{n} is a prime number")
    break
# Out:
# enter a number: 131
# the given number is a palindrome
# 131 is a prime number

# %%
import random
n = int(input("enter number of persons: "))
k = random.randint(1,n)
print(k)
L = []
for i in range(1,n+1):
  L.append(i)
nums = []
for i in range(k+1,len(L),2):
  nums.append(i)
nums
# Out:
# enter number of persons: 18
# 14
# [15, 17]

# %%
def josephus(n):
    participants = list(range(1, n + 1))
    index = 0
    while len(participants) > 1:
        index = (index + 1) % len(participants)
        participants.pop(index)
    return participants[0]
print(josephus(7))
print(josephus(13))
print(josephus(16))
# Out:
# 7
# 11
# 1
